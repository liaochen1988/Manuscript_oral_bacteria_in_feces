# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from copy import deepcopy
from skbio.diversity.alpha import shannon
from sklearn.metrics import pairwise_distances
from collections import Counter
import scipy.cluster.hierarchy as sch
from scipy.spatial.distance import squareform
from scipy.stats import spearmanr,kendalltau
from scipy.cluster.hierarchy import leaves_list
from scipy import stats
from statsmodels.stats.multitest import multipletests

# %%
# read sample meta data and eliminate samples without transplant day
df_sample = pd.read_csv('tblASVsamples.csv', index_col=0)
df_sample = df_sample[df_sample.DayRelativeToNearestHCT.notnull()]

# read count data
df_count_stacked = pd.read_csv('tblcounts_asv_melt.csv')
df_count_stacked = pd.pivot_table(df_count_stacked, index='SampleID', columns='ASV', values='Count', aggfunc=np.sum).fillna(0)
df_count_stacked = df_count_stacked[df_count_stacked.sum(axis=1)>=1000]
df_count_stacked = df_count_stacked.loc[:, (df_count_stacked != 0).any(axis=0)]
print("min seq depth = %d" %(df_count_stacked.sum(axis=1).min()))
df_relab_asv =  df_count_stacked.div(df_count_stacked.sum(axis=1), axis=0)

# find commmon samples
common_samples = set(df_sample.index).intersection(set(df_relab_asv.index))
df_sample = df_sample.loc[common_samples]
df_relab_asv = df_relab_asv.loc[common_samples]
# Out:
# min seq depth = 1001

# %%
# get oral bacterial fraction
df_blast_100 = pd.read_csv("blast_HMPv35oral/blast_HMPv35oral_p100.txt", sep="\t", comment="#", header=None)
df_blast_100.columns = ['query_accver', 'subject_accver', 'perc_identity', 'alignment_length', 'mismatches', 'gap_opens', 'qstart', 'qend', 'sstart', 'send', 'evalue', 'bitscore']#
df_oral_total = df_relab_asv[set(df_blast_100.query_accver).intersection(df_relab_asv.columns)].sum(axis=1).to_frame()
df_oral_total.columns = ['OralFrac_HMPv35oral']
df_oral_total = df_oral_total.reset_index('SampleID').sort_values(['OralFrac_HMPv35oral','SampleID']).set_index('SampleID')
df_oral_asv = pd.merge(df_oral_total, df_relab_asv, left_index=True, right_index=True, how='inner')

# %%
res = []
for col in df_oral_asv.columns:
    rho, p = stats.spearmanr(df_oral_asv.OralFrac_HMPv35oral, df_oral_asv[col])
    res.append([col, rho, p])
df_res = pd.DataFrame(res, columns=['ASV','Coef','P'])
df_res = df_res[df_res.P.notnull()]
df_res['Padj'] = multipletests(df_res['P'], alpha=0.05, method='bonferroni')[1]
df_res['Is_Oral'] = 0
df_res.loc[df_res.ASV.isin(df_blast_100.query_accver), 'Is_Oral'] = 1
df_tax = pd.read_csv('tblASVtaxonomy_silva138_v4v5_filter.csv')
df_res = pd.merge(df_res, df_tax[['ASV','LowestClassifiedTaxa']], left_on='ASV', right_on='ASV', how='left')
df_res.head()
# Out:
# /Users/liaoc/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4529: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
#                    ASV      Coef             P          Padj  Is_Oral  \
# 0  OralFrac_HMPv35oral  1.000000  0.000000e+00  0.000000e+00        0
# 1                ASV_1  0.056296  8.713971e-09  1.375152e-04        0
# 2               ASV_10 -0.035679  2.673379e-04  1.000000e+00        0
# 3              ASV_100 -0.095006  2.359289e-22  3.723194e-18        0
# 4             ASV_1000  0.009375  3.382954e-01  1.000000e+00        0
#
#   LowestClassifiedTaxa
# 0                  NaN
# 1        Lactobacillus
# 2              Blautia
# 3          Bacteroides
# 4           Romboutsia

# %%
df_res[(df_res.Padj<0.05) & (df_res.Is_Oral==1)].sort_values('Coef', ascending=False).head(20)
# Out:
#             ASV      Coef              P           Padj  Is_Oral  \
# 14881     ASV_8  0.722416   0.000000e+00   0.000000e+00        1
# 6161     ASV_32  0.433785   0.000000e+00   0.000000e+00        1
# 10657    ASV_51  0.404635   0.000000e+00   0.000000e+00        1
# 1129    ASV_128  0.401745   0.000000e+00   0.000000e+00        1
# 13440   ASV_635  0.348211  3.785401e-295  5.973741e-291        1
# 5497    ASV_264  0.307141  9.292643e-227  1.466472e-222        1
# 3189    ASV_175  0.288073  1.603179e-198  2.529976e-194        1
# 5403    ASV_258  0.283145  1.426814e-191  2.251656e-187        1
# 5989    ASV_310  0.281201  7.193112e-189  1.135145e-184        1
# 5218    ASV_247  0.278383  5.459238e-185  8.615224e-181        1
# 9153    ASV_457  0.269379  6.742194e-173  1.063986e-168        1
# 2203    ASV_150  0.258876  2.270662e-159  3.583332e-155        1
# 4880    ASV_234  0.242822  7.136643e-140  1.126234e-135        1
# 3711    ASV_189  0.225997  6.187225e-121  9.764059e-117        1
# 6588    ASV_342  0.211898  3.228240e-106  5.094485e-102        1
# 13111   ASV_616  0.199897   1.672338e-94   2.639116e-90        1
# 5663    ASV_288  0.198992   1.195991e-93   1.887394e-89        1
# 2876   ASV_1657  0.188090   1.076473e-83   1.698782e-79        1
# 9654    ASV_472  0.184424   1.758467e-80   2.775037e-76        1
# 2667    ASV_161  0.183605   8.999630e-80   1.420232e-75        1
#
#       LowestClassifiedTaxa
# 14881        Streptococcus
# 6161         Streptococcus
# 10657          Actinomyces
# 1129           Actinomyces
# 13440       Granulicatella
# 5497           Veillonella
# 3189         Streptococcus
# 5403           Actinomyces
# 5989                Rothia
# 5218       Veillonellaceae
# 9153             Atopobium
# 2203               Gemella
# 4880         Mogibacterium
# 3711           Veillonella
# 6588         Streptococcus
# 13111           Parvimonas
# 5663                Rothia
# 2876                 F0332
# 9654           Abiotrophia
# 2667                Rothia

# %%
df_res[(df_res.Padj<0.05) & (df_res.Is_Oral==0)].sort_values('Padj').head(20)
# Out:
#                        ASV      Coef              P           Padj  Is_Oral  \
# 0      OralFrac_HMPv35oral  1.000000   0.000000e+00   0.000000e+00        0
# 2636                ASV_16  0.444504   0.000000e+00   0.000000e+00        0
# 14948               ASV_81  0.360918   0.000000e+00   0.000000e+00        0
# 10444              ASV_500  0.324865  5.680867e-255  8.964976e-251        0
# 12029             ASV_5760  0.296320  1.803815e-210  2.846600e-206        0
# 8206              ASV_4172  0.267265  3.992807e-170  6.301049e-166        0
# 7190               ASV_379  0.256930  6.228283e-157  9.828854e-153        0
# 710                ASV_115  0.244145  1.994888e-141  3.148133e-137        0
# 3807              ASV_1905  0.229846  3.914647e-125  6.177705e-121        0
# 4916               ASV_239  0.229530  8.703054e-125  1.373429e-120        0
# 4839               ASV_228  0.228734  6.509163e-124  1.027211e-119        0
# 5355              ASV_2566  0.222236  6.601509e-117  1.041784e-112        0
# 14145              ASV_691  0.201255   8.610037e-96   1.358750e-91        0
# 1505               ASV_134  0.200654   3.210908e-95   5.067134e-91        0
# 2529               ASV_157  0.197098   7.075270e-92   1.116548e-87        0
# 3994              ASV_1964  0.192354   1.622499e-87   2.560465e-83        0
# 7817              ASV_4044  0.190355   1.031830e-85   1.628330e-81        0
# 10866              ASV_519  0.187954   1.422051e-83   2.244138e-79        0
# 14085              ASV_684  0.186630   2.088247e-82   3.295463e-78        0
# 15341             ASV_8736  0.177858   6.792693e-75   1.071955e-70        0
#
#             LowestClassifiedTaxa
# 0                            NaN
# 2636               Streptococcus
# 14948                Veillonella
# 10444                  Scardovia
# 12029            Lactobacillales
# 8206             Lactobacillales
# 7190                  Firmicutes
# 710                  Veillonella
# 3807   Erysipelatoclostridiaceae
# 4916                 Lactococcus
# 4839               Streptococcus
# 5355             Lachnospiraceae
# 14145              Streptococcus
# 1505                Mitochondria
# 2529                 Actinomyces
# 3994         Erysipelotrichaceae
# 7817                    Bacteria
# 10866            Lachnospiraceae
# 14085              Solobacterium
# 15341                 Firmicutes
